# %% [markdown]
# <a href="https://colab.research.google.com/github/MalikaSh23/MalikaSh23/blob/main/virtual_brands_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# Creating the DataFrame
df = pd.read_csv('/content/top-virtual-brand-analysis-clean.csv')

# Grouping by STATECODE to count the number of restaurants per state
state_counts = df.groupby("STATECODE").size().reset_index(name='count')

# Creating the treemap with data labels
fig = px.treemap(state_counts,
                 path=['STATECODE'],
                 values='count',
                 title="Treemap of Restaurant Counts by State")

# Customize the data labels
fig.update_traces(textinfo="label+value")

# Displaying the treemap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bc4abc2f-08b6-465b-b275-c9372108d200" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc4abc2f-08b6-465b-b275-c9372108d200")) {                    Plotly.newPlot(                        "bc4abc2f-08b6-465b-b275-c9372108d200",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["AK","AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"labels":["AK","AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","parents":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",""],"values":[7,92,123,454,3097,400,280,97,77,1629,665,36,102,58,570,316,96,192,136,406,526,30,502,207,219,63,11,518,17,109,29,609,120,226,1206,724,150,134,706,35,202,22,432,1612,126,589,7,236,171,55,34],"type":"treemap","textinfo":"label+value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...

# %%
df.head()
# Out:
#             RESTAURANT_NAME                     TYPE_OF_RESTAURANT  \
# 0  SCOOPED COOKIE DOUGH BAR  Ice Cream and Frozen Yogurt, Desserts
# 1  SCOOPED COOKIE DOUGH BAR  Ice Cream and Frozen Yogurt, Desserts
# 2  SCOOPED COOKIE DOUGH BAR  Ice Cream and Frozen Yogurt, Desserts
# 3  SCOOPED COOKIE DOUGH BAR  Ice Cream and Frozen Yogurt, Desserts
# 4  SCOOPED COOKIE DOUGH BAR  Ice Cream and Frozen Yogurt, Desserts
#
#             CITY STATECODE    ZIP   RUN_ID  Check top or not   \
# 0      SANTA ANA        CA  92707  Aug2024                286
# 1  SAN FRANCISCO        CA  94107  Aug2024                286
# 2     LONG BEACH        CA  90813  Aug2024                286
# 3         AUSTIN        TX  78751  Aug2024                286
# 4     COSTA MESA        CA  92627  Aug2024                286
#
#   VIRTUAL_BRAND_ID Food Specialty Type Food Specialty   Cuisine
# 0          VB00214            Desserts   Cookie Dough  American
# 1          VB00215            Desserts   Cookie Dough  American
# 2          VB00216            Desserts   Cookie Dough  American
# 3          VB00217            Desserts   Cookie Dough  American
# 4          VB00218            Desserts   Cookie Dough  American

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18460 entries, 0 to 18459
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RESTAURANT_NAME      18460 non-null  object
#  1   TYPE_OF_RESTAURANT   18460 non-null  object
#  2   CITY                 18460 non-null  object
#  3   STATECODE            18460 non-null  object
#  4   ZIP                  18460 non-null  int64
#  5   RUN_ID               18460 non-null  object
#  6   Check top or not     18460 non-null  int64
#  7   VIRTUAL_BRAND_ID     18460 non-null  object
#  8   Food Specialty Type  18460 non-null  object
#  9   Food Specialty       18382 non-null  object
#  10  Cuisine              18460 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.5+ MB

# %%
import pandas as pd
import plotly.express as px

# Filter data to include only the states CA, FL, TX, and NY
filtered_df = df[df['STATECODE'].isin(['CA', 'FL', 'TX', 'NY'])]

# Group by STATECODE and Food Specialty Type to get counts
cuisine_counts = (filtered_df
                  .groupby(['STATECODE', 'Food Specialty'])
                  .size()
                  .reset_index(name='count'))

# Get the top 10 food specialties per state by applying head(10) after sorting
top_cuisines = (cuisine_counts
                .sort_values(['STATECODE', 'count'], ascending=[True, False])
                .groupby('STATECODE')
                .apply(lambda x: x.head(10))
                .reset_index(drop=True))

# Find the maximum count for setting a uniform Y-axis range
max_count = top_cuisines['count'].max()

# Visualize the top 10 food specialties using a bar plot with simplified labels
fig = px.bar(top_cuisines,
             x='Food Specialty',
             y='count',
             color='STATECODE',
             facet_col='STATECODE',
             title="Top 10 Specialties in Selected States",
             labels={'count': 'Number of Restaurants',
                     'Food Specialty': 'Food Specialty'},
             height=600)

# Update layout for a common Y-axis title and uniform Y-axis range
fig.update_layout(showlegend=False,
                  title={'text': "Top 10 Cuisines in CA, FL, TX, and NY", 'x':0.5},
                  margin=dict(t=50, l=50, r=50, b=50),
                  yaxis_title='Number of Restaurants')

# Set the same Y-axis range for all facets
fig.update_yaxes(range=[0, max_count])

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9f27c029-623f-4561-9a6a-37638bcaa929" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f27c029-623f-4561-9a6a-37638bcaa929")) {                    Plotly.newPlot(                        "9f27c029-623f-4561-9a6a-37638bcaa929",                        [{"alignmentgroup":"True","hovertemplate":"STATECODE=CA\u003cbr\u003eFood Specialty=%{x}\u003cbr\u003eNumber of Restaurants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CA","offsetgroup":"CA","orientation":"v","showlegend":true,"textposition":"auto","x":["Pizza","Burgers","Burritos","Grilled Sandwiches","Wings","Cookies","Cookie Dough","Grilled Cheese food items","Chicken & Hot Dogs","Cheesesteaks"],"xaxis":"x","y":[689,405,400,250,182,144,132,93,75,72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"STATECODE=FL\u003cbr\u003eFood Specialty=%{x}\u003cbr\u003eNumber of Restaurants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FL","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"FL","offsetgroup":"FL","orientation":"v","showlegend":true,"textposition":"auto","x":["Pizza","Burgers","Wings","Cheesesteaks","Chicken Tenders","Grilled Sandwiches","Pasta & Salads","Chicken & Hot Dogs","Coffee and Desserts","Sandwiches"],"xaxis":"x2","y":[350,278,245,125,82,62,59,46,42,41],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"STATECODE=NY\u003cbr\u003eFood Specialty=%{x}\u003cbr\u003eNumber of Restaurants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NY","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"NY","offsetgroup":"NY","orientation":"v","showlegend":true,"textposition":"auto","x":["Burritos","Pizza","Burgers","Cheesesteak, Sandwiches","Wings","Grilled Cheese food items","Sandwiches","Pasta","Cheesesteaks","Noodles"],"xaxis":"x3","y":[194,144,142,112,97,70,58,43,41,35],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"STATECODE=TX\u003cbr\u003eFood Specialty=%{x}\u003cbr\u003eNumber of Restaurants=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TX","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"TX","offsetgroup":"TX","orientation":"v","showlegend":true,"textposition":"auto","x":["Burgers","Wings","Pizza","Burritos","Sandwiches","Cheesesteaks","Grilled Sandwiches","Chicken & Hot Dogs","Cookies","Chicken Tenders"],"xaxis":"x4","y":[324,246,170,127,120,105,97,76,48,37],"yaxis":"y4","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3 ...

# %%
6

# %%
top_cuisines[top_cuisines['STATECODE']=='RI']
# Out:
# Empty DataFrame
# Columns: [STATECODE, Food Specialty, count]
# Index: []

# %%
import pandas as pd
import plotly.express as px

# Group by STATECODE and RESTAURANT_NAME to get the count of each restaurant's locations in each state
restaurant_counts = (df.groupby(['STATECODE', 'RESTAURANT_NAME'])
                     .size()
                     .reset_index(name='location_count'))

# Sort by STATECODE and location_count in descending order
sorted_restaurant_counts = restaurant_counts.sort_values(['STATECODE', 'location_count'], ascending=[True, False])

# Get the biggest player (restaurant with the most locations) in each state
biggest_player_per_state = sorted_restaurant_counts.groupby('STATECODE').head(1).reset_index(drop=True)

# Now we want to find the top 7 restaurants across all states
top_7_restaurants = biggest_player_per_state.nlargest(7, 'location_count')

# Create a new column 'Category' to categorize into 'Top 7' or 'Other'
biggest_player_per_state['Category'] = biggest_player_per_state['RESTAURANT_NAME'].apply(
    lambda x: x if x in top_7_restaurants['RESTAURANT_NAME'].values else 'OTHERS'
)

# Group by 'Category' to get the counts for the pie chart
pie_data = (biggest_player_per_state.groupby('Category')['location_count']
            .sum()
            .reset_index())

# Ensure 'OTHERS' is at the end of the list and include all categories
categories = [cat for cat in pie_data['Category'] if cat != 'OTHERS'] + ['OTHERS']
pie_data = pie_data.set_index('Category').reindex(categories).reset_index()

# Create the pie chart with data labels
fig = px.pie(pie_data,
             values='location_count',
             names='Category',
             title='Top 7 Biggest Virtual Brand Players vs. Other',
             hole=0.5)

# Update textinfo to include the count and percentage in the data labels
fig.update_traces(textinfo='label+percent+value',
                  textfont_size=8)

# Update layout to ensure 'OTHERS' is at the bottom in the legend
fig.update_layout(
    legend_title_text='Restaurant Category',
    legend=dict(
        orientation="v",
        yanchor="top",
        y=0.5,
        xanchor="left",
        x=1.05,
        traceorder='reversed'  # Reverse the order so 'OTHERS' is at the bottom
    )
)

# Show the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="00308f11-b984-4702-8048-f204bb426e66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00308f11-b984-4702-8048-f204bb426e66")) {                    Plotly.newPlot(                        "00308f11-b984-4702-8048-f204bb426e66",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"Category=%{label}\u003cbr\u003elocation_count=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["BROOKLYN CALZONES","CHEESESTEAK DADDY","IT'S JUST WINGS","SUNNY & FINE'S BREAKFAST BURRITOS","THE ORIGINAL HOT CHICKEN","OTHERS"],"legendgroup":"","name":"","showlegend":true,"values":[506,84,291,616,176,912],"type":"pie","textfont":{"size":8},"textinfo":"label+percent+value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...

# %%
import pandas as pd
import plotly.express as px

# Assuming 'state_counts' DataFrame is ready as before

# Create a choropleth map
fig = px.choropleth(state_counts,
                    locations='STATECODE',
                    locationmode='USA-states',
                    color='count',
                    scope='usa',
                    color_continuous_scale='Blues',
                    labels={'count': 'Number of Virtual Restaurants'},
                    title='Number of Virtual Restaurants by State')

# Update layout for better spacing and adjust the size of the map and legend
fig.update_layout(
    geo=dict(
        bgcolor='rgba(0,0,0,0)',  # Transparent background
        showframe=False,          # Remove the frame around the map
        projection_scale=1.1      # Adjust the scale to make the map bigger
    ),
    title={'x': 0.5},
    margin={"r": 0, "t": 50, "l": 0, "b": 0},  # Adjust margins to increase map size
    coloraxis_colorbar=dict(
        title="Number of Virtual Restaurants",
        thicknessmode="pixels",  # Set thickness in pixels
        thickness=15,            # Make the legend thinner
        lenmode="fraction",      # Set length in fraction of the map
        len=0.5,                 # Make the legend shorter
        yanchor="middle",        # Center the legend vertically
        y=0.5                    # Position the legend at the center of the map
    )
)

# Show the map
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aedb8623-07e7-4e3d-bda3-dea855cb1e20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aedb8623-07e7-4e3d-bda3-dea855cb1e20")) {                    Plotly.newPlot(                        "aedb8623-07e7-4e3d-bda3-dea855cb1e20",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"STATECODE=%{location}\u003cbr\u003eNumber of Virtual Restaurants=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[7,92,123,454,3097,400,280,97,77,1629,665,36,102,58,570,316,96,192,136,406,526,30,502,207,219,63,11,518,17,109,29,609,120,226,1206,724,150,134,706,35,202,22,432,1612,126,589,7,236,171,55,34],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"co ...

# %%
df_virtual=pd.read_csv('/content/Summary of Anlaysis of Virtual Brands - analysis data.csv')

# %%
df_virtual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18460 entries, 0 to 18459
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RESTAURANT_NAME      18460 non-null  object
#  1   TYPE_OF_RESTAURANT   18460 non-null  object
#  2   CITY                 18460 non-null  object
#  3   STATECODE            18460 non-null  object
#  4   ZIP                  18460 non-null  int64
#  5   RUN_ID               18460 non-null  object
#  6   COUNT OF OUTLETS     18460 non-null  int64
#  7   VIRTUAL_BRAND_ID     18460 non-null  object
#  8   Food Specialty Type  18460 non-null  object
#  9   Food Specialty       18382 non-null  object
#  10  Cuisine              18460 non-null  object
#  11  Remark               18460 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 1.7+ MB

# %%
# Calculate the proportion of each Remark category in the entire dataset
us_proportions = (df_virtual['Remark']
                  .value_counts(normalize=True)
                  .reset_index())
us_proportions.columns = ['Remark', 'Proportion']

# Visualize the proportions with a pie chart
fig_us = px.pie(us_proportions,
                values='Proportion',
                names='Remark',
                title='Virtual only or not?',
                hole=0.3)

# Show the pie chart
fig_us.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2301ab5-4831-4377-ad7f-4697283c0dfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2301ab5-4831-4377-ad7f-4697283c0dfb")) {                    Plotly.newPlot(                        "c2301ab5-4831-4377-ad7f-4697283c0dfb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Remark=%{label}\u003cbr\u003eProportion=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Virtual and Physical","Virtual Only"],"legendgroup":"","name":"","showlegend":true,"values":[0.8686890574214517,0.13131094257854822],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"c ...

# %%
# Calculate the count of each Remark category within each state
state_remark_counts = df_virtual.groupby(['STATECODE', 'Remark']).size().reset_index(name='Count')

# Calculate the total count of restaurants in each state
state_total_counts = df_virtual.groupby('STATECODE').size().reset_index(name='Total')

# Merge the two DataFrames to calculate proportions
state_proportions = pd.merge(state_remark_counts, state_total_counts, on='STATECODE')

# Calculate the proportion of each Remark category within each state
state_proportions['Proportion'] = state_proportions['Count'] / state_proportions['Total']

# Display the state-wise proportions DataFrame
print(state_proportions.head())
# Out:
#   STATECODE                Remark  Count  Total  Proportion
# 0        AK          Virtual Only      1      7    0.142857
# 1        AK  Virtual and Physical      6      7    0.857143
# 2        AL          Virtual Only     12     92    0.130435
# 3        AL  Virtual and Physical     80     92    0.869565
# 4        AR          Virtual Only      7    123    0.056911

# %%
# Visualize the state-wise proportions with a faceted bar chart
fig_state = px.bar(state_proportions,
                   x='Remark',
                   y='Proportion',
                   color='Remark',
                   facet_col='STATECODE',
                   facet_col_wrap=5,  # Adjusts the number of columns in the facet
                   title='Proportion of Restaurants by Remark in Each State',
                   height=1000)

# Update layout for better spacing
fig_state.update_layout(showlegend=False)

# Show the bar chart
fig_state.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="53be78a5-419b-40d1-99e3-0c09f670e740" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53be78a5-419b-40d1-99e3-0c09f670e740")) {                    Plotly.newPlot(                        "53be78a5-419b-40d1-99e3-0c09f670e740",                        [{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=AK\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":true,"textposition":"auto","x":["Virtual Only"],"xaxis":"x51","y":[0.14285714285714285],"yaxis":"y51","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=AL\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x52","y":[0.13043478260869565],"yaxis":"y52","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=AR\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x53","y":[0.056910569105691054],"yaxis":"y53","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=AZ\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x54","y":[0.11013215859030837],"yaxis":"y54","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=CA\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x55","y":[0.08427510494026477],"yaxis":"y55","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=CO\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x46","y":[0.185],"yaxis":"y46","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=CT\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x47","y":[0.09285714285714286],"yaxis":"y47","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Remark=%{x}\u003cbr\u003eSTATECODE=DC\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Virtual Only","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Virtual Only","offsetgroup":"Virtual Only","orientation":"v","showlegend":false,"textposition":"auto","x":["Virtual Only"],"xaxis":"x48","y":[0.030927835051546393],"yaxis":"y48","type":"bar"},{"alignm ...
